# %%
import numpy as np
import json

from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression

# %%
def reader(path_params):
    with open(path_params, "r") as file:
        params = json.load(file)
    print(params)
    return params

# %%
params_global = reader("params/synthetic.json")
# Out:
# {'data': {'sample_size': 1000, 'label_number': 10, 'avg_label_number': 4, 'cal_size': 0.5, 'proper_cal_size': 0.5}, 'predictor': {'log_lam_min': -1, 'log_lam_max': 4, 'lam_number': 100}}

# %%
lam_grid = np.logspace(
    params_global["predictor"]["log_lam_min"],
    params_global["predictor"]["log_lam_max"],
    params_global["predictor"]["lam_number"],
)
classifiers = [OneVsRestClassifier(LogisticRegression(C=1 / lam)) for lam in lam_grid]
