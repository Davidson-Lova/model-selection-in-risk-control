# %%
import numpy as np
import json

from sklearn.datasets import make_multilabel_classification

from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier

import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd

# %%
import sys
sys.path.append("..")

# %%
from src.data.formatting import resample_data_set
from src.conformal_risk_control.fnr import compute_prediction_set
from src.model_selection.fnr_oracle import compute_oracle_prediction_set
from src.model_selection.fnr_upper import compute_upper_prediction_set
from src.model_selection.fnr_split import select_predictor_index

# %%
def reader(path_params):
    with open(path_params, "r") as file:
        params = json.load(file)
    print(params)
    return params

# %%
def generate_data_set(params):
    inputs_, outputs_ = make_multilabel_classification(
        n_samples=params["sample_size"] + 1,
        n_features=params["feature_number"],
        n_classes=params["label_number"],
        n_labels=params["avg_label_number"],
        allow_unlabeled=False,
        return_indicator=True,
    )
    return inputs_, outputs_

# %%
params_global = reader("params/experiment_2.json")
lam = 10
# Out:
# {'data': {'sample_size': 500, 'feature_number': 300, 'label_number': 10, 'avg_label_number': 4, 'cal_size': 0.3, 'proper_cal_size': 0.5}, 'predictor': {'n_estimators_min': 10, 'n_estimators_max': 100, 'criterion': ['gini', 'entropy'], 'lam_numbers': ['14', '22', '32', '38']}, 'risk': {'control_level': 0.25}}

# %%
complete_n_estimators_grid = np.arange(params_global["predictor"]["n_estimators_min"], params_global["predictor"]["n_estimators_max"]+1)
np.random.shuffle(complete_n_estimators_grid)
n_estimators_grid = complete_n_estimators_grid[: 11]
print(n_estimators_grid)
# Out:
# [89 26 86 66 73 18 99 91 53 32 76]

# %%
parameter_grid =  np.array(
    [
        {"n_estimators": n_estimators, "criterion": criterion}
        for n_estimators in n_estimators_grid
        for criterion in params_global["predictor"]["criterion"]
    ], dtype = object
)
print(parameter_grid)
# Out:
# [{'n_estimators': np.int64(89), 'criterion': 'gini'}
#  {'n_estimators': np.int64(89), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(26), 'criterion': 'gini'}
#  {'n_estimators': np.int64(26), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(86), 'criterion': 'gini'}
#  {'n_estimators': np.int64(86), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(66), 'criterion': 'gini'}
#  {'n_estimators': np.int64(66), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(73), 'criterion': 'gini'}
#  {'n_estimators': np.int64(73), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(18), 'criterion': 'gini'}
#  {'n_estimators': np.int64(18), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(99), 'criterion': 'gini'}
#  {'n_estimators': np.int64(99), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(91), 'criterion': 'gini'}
#  {'n_estimators': np.int64(91), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(53), 'criterion': 'gini'}
#  {'n_estimators': np.int64(53), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(32), 'criterion': 'gini'}
#  {'n_estimators': np.int64(32), 'criterion': 'entropy'}
#  {'n_estimators': np.int64(76), 'criterion': 'gini'}
#  {'n_estimators': np.int64(76), 'criterion': 'entropy'}]

# %%
predictors = [
    OneVsRestClassifier(RandomForestClassifier(**parameter)) for parameter in parameter_grid
]

# %%
rep_number = 100

# %%
results = {
    "size":{
        "Oracle":[],
        "Upper":[],
        "Split":[],
        "Output":[],
    }, "FNR":{
        "Oracle":[],
        "Upper":[],
        "Split":[],
    }
}

# %%
for rep_index in tqdm(range(rep_number)):
    inputs_, outputs_ = generate_data_set(params_global["data"])

    (
        (scaled_inputs_train, outputs_train),
        (scaled_inputs_calibration, outputs_calibration),
        (
            scaled_inputs_selection,
            scaled_inputs_proper_cal,
            outputs_selection,
            outputs_proper_cal,
        ),
        (scaled_input_test, output_test),
    ) = resample_data_set(inputs_, outputs_, params_global["data"]["cal_size"], params_global["data"]["proper_cal_size"])


    for predictor in predictors:
        predictor.fit(scaled_inputs_train, outputs_train)


    probas_calibration_per_predictor = [
        predictor.predict_proba(scaled_inputs_calibration) for predictor in predictors
    ]
    proba_test_per_predictor = [
        predictor.predict_proba(scaled_input_test) for predictor in predictors
    ]
    oracle_prediction_set = compute_oracle_prediction_set(
        outputs_calibration,
        probas_calibration_per_predictor,
        output_test,
        proba_test_per_predictor,
        params_global["risk"]["control_level"],
    )

    
    upper_prediction_set = compute_upper_prediction_set(
        outputs_calibration,
        probas_calibration_per_predictor,
        proba_test_per_predictor,
        params_global["risk"]["control_level"],
    )



    probas_selection_per_predictor = [
        predictor.predict_proba(scaled_inputs_selection) for predictor in predictors
    ]
    split_predictor_index = select_predictor_index(
        outputs_selection, probas_selection_per_predictor, params_global["risk"]["control_level"]
    )
    split_prediction_set = compute_prediction_set(
        predictors[split_predictor_index],
        scaled_inputs_proper_cal,
        outputs_proper_cal,
        scaled_input_test,
        params_global["risk"]["control_level"]
    )

    oracle_fnr = (
        np.logical_and(output_test, np.logical_not(oracle_prediction_set)).sum(axis=1)
        / output_test.sum(axis=1)
    ).item()
    upper_fnr = (
        np.logical_and(output_test, np.logical_not(upper_prediction_set)).sum(axis=1)
        / output_test.sum(axis=1)
    ).item()
    split_fnr = (
        np.logical_and(output_test, np.logical_not(split_prediction_set)).sum(axis=1)
        / output_test.sum(axis=1)
    ).item()
    
    results["FNR"]["Oracle"].append(oracle_fnr)
    results["FNR"]["Upper"].append(upper_fnr)
    results["FNR"]["Split"].append(split_fnr)

    results["size"]["Oracle"].append(oracle_prediction_set.sum())
    results["size"]["Upper"].append(upper_prediction_set.sum())
    results["size"]["Split"].append(split_prediction_set.sum())
    results["size"]["Output"].append(output_test.sum())

    
    print("Average oracle prediction-set size: {}".format(np.mean(results["size"]["Oracle"])))
    print("Average output size: {}".format(np.mean(results["size"]["Output"])))
    print("Average split prediction-set size: {}".format(np.mean(results["size"]["Split"])))
    print("Average upper prediction-set size: {}".format(np.mean(results["size"]["Upper"])))
# Out:
#   1%|          | 1/100 [00:28<46:26, 28.14s/it]
# Average oracle prediction-set size: 6.0
# Average output size: 2.0
# Average split prediction-set size: 7.0
# Average upper prediction-set size: 7.0
#   2%|▏         | 2/100 [00:56<46:26, 28.43s/it]
# Average oracle prediction-set size: 5.0
# Average output size: 2.0
# Average split prediction-set size: 6.5
# Average upper prediction-set size: 5.5
#   3%|▎         | 3/100 [01:28<48:36, 30.07s/it]
# Average oracle prediction-set size: 4.666666666666667
# Average output size: 2.0
# Average split prediction-set size: 5.666666666666667
# Average upper prediction-set size: 5.333333333333333
#   4%|▍         | 4/100 [01:59<48:28, 30.30s/it]
# Average oracle prediction-set size: 5.0
# Average output size: 2.75
# Average split prediction-set size: 6.0
# Average upper prediction-set size: 6.0
#   5%|▌         | 5/100 [02:28<47:14, 29.83s/it]
# Average oracle prediction-set size: 5.2
# Average output size: 2.6
# Average split prediction-set size: 6.2
# Average upper prediction-set size: 6.2
#   6%|▌         | 6/100 [02:57<46:15, 29.53s/it]
# Average oracle prediction-set size: 5.333333333333333
# Average output size: 3.3333333333333335
# Average split prediction-set size: 6.333333333333333
# Average upper prediction-set size: 6.166666666666667
#   7%|▋         | 7/100 [03:26<45:25, 29.31s/it]
# Average oracle prediction-set size: 5.571428571428571
# Average output size: 3.7142857142857144
# Average split prediction-set size: 6.142857142857143
# Average upper prediction-set size: 6.285714285714286
#   8%|▊         | 8/100 [03:56<45:25, 29.63s/it]
# Average oracle prediction-set size: 5.625
# Average output size: 4.125
# Average split prediction-set size: 6.0
# Average upper prediction-set size: 6.25
#   9%|▉         | 9/100 [04:25<44:29, 29.34s/it]
# Average oracle prediction-set size: 5.333333333333333
# Average output size: 4.444444444444445
# Average split prediction-set size: 5.888888888888889
# Average upper prediction-set size: 6.111111111111111
#  10%|█         | 10/100 [04:53<43:20, 28.89s/it]
# Average oracle prediction-set size: 5.4
# Average output size: 4.2
# Average split prediction-set size: 5.9
# Average upper prediction-set size: 6.2
#  11%|█         | 11/100 [05:21<42:49, 28.87s/it]
# Average oracle prediction-set size: 5.454545454545454
# Average output size: 4.0
# Average split prediction-set size: 6.0
# Average upper prediction-set size: 6.363636363636363
#  12%|█▏        | 12/100 [05:50<41:59, 28.63s/it]
# Average oracle prediction-set size: 5.416666666666667
# Average output size: 3.9166666666666665
# Average split prediction-set size: 5.916666666666667
# Average upper prediction-set size: 6.333333333333333
#  13%|█▎        | 13/100 [06:18<41:20, 28.51s/it]
# Average oracle prediction-set size: 5.461538461538462
# Average output size: 3.769230769230769
# Average split prediction-set size: 6.0
# Average upper prediction-set size: 6.384615384615385
#  14%|█▍        | 14/100 [06:46<40:53, 28.53s/it]
# Average oracle prediction-set size: 5.428571428571429
# Average output size: 3.9285714285714284
# Average split prediction-set size: 5.928571428571429
# Average upper prediction-set size: 6.357142857142857
#  15%|█▌        | 15/100 [07:15<40:23, 28.51s/it]
# Average oracle prediction-set size: 5.533333333333333
# Average output size: 3.7333333333333334
# Average split prediction-set size: 6.0
# Average upper prediction-set size: 6.466666666666667
#  16%|█▌        | 16/100 [07:44<40:00, 28.58s/it]
# Average oracle prediction-set size: 5.625
# Average output size: 3.8125
# Average split prediction-set size: 6.0625
# Average upper prediction-set size: 6.5625
#  17%|█▋        | 17/100 [08:12<39:33, 28.60s/it]
# Average oracle prediction-set size: 5.588235294117647
# Average output size: 3.764705882352941
# Average split prediction-set size: 6.117647058823529
# Average upper prediction-set size: 6.647058823529412
#  18%|█▊        | 18/100 [08:40<38:55, 28.48s/it]
# Average oracle prediction-set size: 5.5
# Average output size: 3.6666666666666665
# Average split prediction-set size: 6.0
# Average upper prediction-set size: 6.555555555555555
#  19%|█▉        | 19/100 [09:08<38:17, 28.36s/it]
# Average oracle prediction-set size: 5.473684210526316
# Average output size: 3.6842105263157894
# Average split prediction-set size: 6.0
# Average upper prediction-set size: 6.526315789473684
#  20%|██        | 20/100 [09:37<37:46, 28.33s/it]
# Average oracle prediction-set size: 5.45
# Average output size: 3.65
# Average split prediction-set size: 5.9
# Average upper prediction-set size: 6.45
#  21%|██        | 21/100 [10:05<37:18, 28.34s/it]
# Average oracle prediction-set size: 5.476190476190476
# Average output size: 3.7142857142857144
# Average split prediction-set size: 5.857142857142857
# Average upper prediction-set size: 6.428571428571429
#  22%|██▏       | 22/100 [10:34<37:11, 28.60s/it]
# Average oracle prediction-set size: 5.5
# Average output size: 3.8181818181818183
# Average split prediction-set size: 5.863636363636363
# Average upper prediction-set size: 6.454545454545454
#  23%|██▎       | 23/100 [11:03<36:47, 28.67s/it]
# Average oracle prediction-set size: 5.478260869565218
# Average output size: 3.9130434782608696
# Average split prediction-set size: 5.826086956521739
# Average upper prediction-set size: 6.391304347826087
#  24%|██▍       | 24/100 [11:32<36:25, 28.76s/it]
# Average oracle prediction-set size: 5.458333333333333
# Average output size: 3.875
# Average split prediction-set size: 5.791666666666667
# Average upper prediction-set size: 6.416666666666667
#  25%|██▌       | 25/100 [12:01<35:59, 28.79s/it]
# Average oracle prediction-set size: 5.44
# Average output size: 4.08
# Average split prediction-set size: 5.72
# Average upper prediction-set size: 6.4
#  26%|██▌       | 26/100 [12:30<35:28, 28.76s/it]
# Average oracle prediction-set size: 5.461538461538462
# Average output size: 4.153846153846154
# Average split prediction-set size: 5.730769230769231
# Average upper prediction-set size: 6.384615384615385
#  27%|██▋       | 27/100 [12:59<35:03, 28.82s/it]
# Average oracle prediction-set size: 5.481481481481482
# Average output size: 4.074074074074074
# Average split prediction-set size: 5.814814814814815
# Average upper prediction-set size: 6.407407407407407
#  28%|██▊       | 28/100 [13:27<34:29, 28.75s/it]
# Average oracle prediction-set size: 5.5
# Average output size: 4.035714285714286
# Average split prediction-set size: 5.785714285714286
# Average upper prediction-set size: 6.428571428571429
#  29%|██▉       | 29/100 [13:56<34:11, 28.89s/it]
# Average oracle prediction-set size: 5.551724137931035
# Average output size: 4.0
# Average split prediction-set size: 5.827586206896552
# Average upper prediction-set size: 6.448275862068965
#  30%|███       | 30/100 [14:26<33:51, 29.02s/it]
# Average oracle prediction-set size: 5.5
# Average output size: 4.0
# Average split prediction-set size: 5.8
# Average upper prediction-set size: 6.433333333333334
#  31%|███       | 31/100 [14:54<32:59, 28.69s/it]
# Average oracle prediction-set size: 5.516129032258065
# Average output size: 4.032258064516129
# Average split prediction-set size: 5.806451612903226
# Average upper prediction-set size: 6.419354838709677
#  31%|███       | 31/100 [15:19<34:06, 29.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 18
#      14     ) = resample_data_set(inputs_, outputs_, params_global["data"]["cal_size"], params_global["data"]["proper_cal_size"])
#      15
#      16
#      17     for predictor in predictors:
# ---> 18         predictor.fit(scaled_inputs_train, outputs_train)
#      19
#      20
#      21     probas_calibration_per_predictor = [
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\multiclass.py:376, in OneVsRestClassifier.fit(self, X, y, **fit_params)
#     372 columns = (col.toarray().ravel() for col in Y.T)
#     373 # In cases where individual estimators are very fast to train setting
#     374 # n_jobs > 1 in can results in slower performance due to the overhead
#     375 # of spawning threads.  See joblib issue #112.
# --> 376 self.estimators_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     377     delayed(_fit_binary)(
#     378         self.estimator,
#     379         X,
#     380         column,
#     381         fit_params=routed_params.estimator.fit,
#     382         classes=[
#     383             "not %s" % self.label_binarizer_.classes_[i],
#     384             self.label_binarizer_.classes_[i],
#     385         ],
#     386     )
#     387     for i, column in enumerate(columns)
#     388 )
#     390 if hasattr(self.estimators_[0], "n_features_in_"):
#     391     self.n_features_in_ = self.estimators_[0].n_features_in_
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\multiclass.py:96, in _fit_binary(estimator, X, y, fit_params, classes)
#      94 else:
#      95     estimator = clone(estimator)
# ---> 96     estimator.fit(X, y, **fit_params)
#      97 return estimator
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\ensemble\_forest.py:468, in BaseForest.fit(self, X, y, sample_weight)
#     457 trees = [
#     458     self._make_estimator(append=False, random_state=random_state)
#     459     for i in range(n_more_estimators)
#     460 ]
#     462 # Parallel loop: we prefer the threading backend as the Cython code
#     463 # for fitting the trees is internally releasing the Python GIL
#     464 # making threading more efficient than multiprocessing in
#     465 # that case. However, for joblib 0.12+ we respect any
#     466 # parallel_backend contexts set at a higher level,
#     467 # since correctness does not rely on using threads.
# --> 468 trees = Parallel(
#     469     n_jobs=self.n_jobs,
#     470     verbose=self.verbose,
#     471     prefer="threads",
#     472 )(
#     473     delayed(_parallel_build_trees)(
#     474         t,
#     475         self.bootstrap,
#     476         X,
#     477         y,
#     478         _sample_weight,
#     479         i,
#     480         len(trees),
#     481         verbose=self.verbose,
#     482         class_weight=self.class_weight,
#     483         n_samples_bootstrap=n_samples_bootstrap,
#     484         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     485     )
#     486     for i, t in enumerate(trees)
#     487 )
#     489 # Collect newly grown trees
#     490 self.estimators_.extend(trees)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\ensemble\_forest.py:163, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     158         expanded_class_weight = compute_sample_weight(
#     159             "balanced", y, indices=indices
#     160         )
#     161         sample_weight_tree = sample_weight_tree * expanded_class_weight
# --> 163     tree._fit(
#     164         X,
#     165         y,
#     166         sample_weight=sample_weight_tree,
#     167         check_input=False,
#     168         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     169     )
#     170 else:
#     171     tree._fit(
#     172         X,
#     173         y,
#    (...)    176         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     177     )
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\tree\_classes.py:289, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     286 self.n_outputs_ = y.shape[1]
#     288 if is_classification:
# --> 289     check_classification_targets(y)
#     290     y = np.copy(y)
#     292     self.classes_ = []
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\multiclass.py:222, in check_classification_targets(y)
#     210 def check_classification_targets(y):
#     211     """Ensure that target y is of a non-regression type.
#     212
#     213     Only the following target types (as defined in type_of_target) are allowed:
#    (...)    220         Target values.
#     221     """
# --> 222     y_type = type_of_target(y, input_name="y")
#     223     if y_type not in [
#     224         "binary",
#     225         "multiclass",
#    (...)    228         "multilabel-sequences",
#     229     ]:
#     230         raise ValueError(
#     231             f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     232             "classifier, which expects discrete classes on a "
#     233             "regression target with continuous values."
#     234         )
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\multiclass.py:441, in type_of_target(y, input_name, raise_unknown)
#     439 if issparse(first_row_or_val):
#     440     first_row_or_val = first_row_or_val.data
# --> 441 if cached_unique(y).shape[0] > 2 or (y.ndim == 2 and len(first_row_or_val) > 1):
#     442     # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     443     return "multiclass" + suffix
#     444 else:
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\_unique.py:105, in cached_unique(xp, *ys)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\_unique.py:105, in <genexpr>(.0)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\utils\_unique.py:78, in _cached_unique(y, xp)
#      76     pass
#      77 xp, _ = get_namespace(y, xp=xp)
# ---> 78 return xp.unique_values(y)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\externals\array_api_compat\_internal.py:35, in get_xp.<locals>.inner.<locals>.wrapped_f(*args, **kwargs)
#      33 @wraps(f)
#      34 def wrapped_f(*args: object, **kwargs: object) -> object:
# ---> 35     return f(*args, xp=xp, **kwargs)
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\sklearn\externals\array_api_compat\common\_aliases.py:256, in unique_values(x, xp)
#     254 def unique_values(x: Array, /, xp: Namespace) -> Array:
#     255     kwargs = _unique_kwargs(xp)
# --> 256     return xp.unique(
#     257         x,
#     258         return_counts=False,
#     259         return_index=False,
#     260         return_inverse=False,
#     261         **kwargs,
#     262     )
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\numpy\lib\_arraysetops_impl.py:296, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     294     if axis is not None:
#     295         normalize_axis_index(axis, ar.ndim)
# --> 296     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     297                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None,
#     298                     sorted=sorted)
#     299     return _unpack_tuple(ret)
#     301 # axis was specified and not None
#
# File ~\Documents\work\projects\conformal\risk-control\model-selection\code\.venv\Lib\site-packages\numpy\lib\_arraysetops_impl.py:385, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis, sorted)
#     383     aux = ar[perm]
#     384 else:
# --> 385     ar.sort()
#     386     aux = ar
#     387 mask = np.empty(aux.shape, dtype=np.bool)
#
# KeyboardInterrupt:

# %%
print("Average oracle prediction-set size: {}".format(np.mean(results["size"]["Oracle"])))
print("Average output size: {}".format(np.mean(results["size"]["Output"])))
print("Average split prediction-set size: {}".format(np.mean(results["size"]["Split"])))
print("Average upper prediction-set size: {}".format(np.mean(results["size"]["Upper"])))
# Out:
# Average oracle prediction-set size: 5.31
# Average output size: 3.66
# Average split prediction-set size: 5.52
# Average upper prediction-set size: 6.49

# %%
df_volume = pd.DataFrame.from_dict(
    results["size"]
)

# %%
fig, ax = plt.subplots()
box = ax.boxplot(df_volume, patch_artist=True)

# %%
print("Average oracle prediction-set FNR: {}".format(np.mean(results["FNR"]["Oracle"])))
print("Average split prediction-set FNR: {}".format(np.mean(results["FNR"]["Split"])))
print("Average upper prediction-set FNR: {}".format(np.mean(results["FNR"]["Upper"])))
# Out:
# Average oracle prediction-set FNR: 0.23871428571428574
# Average split prediction-set FNR: 0.28064285714285714
# Average upper prediction-set FNR: 0.17135714285714287

# %%
df_fnr = pd.DataFrame.from_dict(
    results["FNR"]
)

# %%
fig, ax = plt.subplots()
box = ax.boxplot(df_fnr, patch_artist=True)
